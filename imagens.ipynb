# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.cm as cm
import matplotlib.lines as lines

import tensorflow as tf
 
import geraChar

P=[]  # Pattern
T=[]  # Target

# %%
(P,T)=geraChar.geraChar()
geraChar.showChar(P)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20504\4179647971.py in <module>
#       1 (P,T)=geraChar.geraChar()
# ----> 2 geraChar.showChar(P[0,:])
#
# c:\Users\lucas\OneDrive\Documentos\UnB\Redes Neurais\Identificação de digitos\geraChar.py in showChar(P)
#     248         plt.subplot(1,16,i+1)
#     249         Pc=CompP(P)
# --> 250         plt.imshow(Pc[i,:].reshape(9,7),cmap=cm.Greys_r)
#     251         plt.axis('off')
#     252     plt.show()
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
